# %% [markdown]
# Question 1
#
# Operators are +, -, *, and /
#
# values are 'hello', -88.8, and 5

# %% [markdown]
# Question 2
#
# Variables are containers for storing data values.
#
# Assigning values to variable
# x=5
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# name = "Shubham"

# %% [markdown]
# Question 3
#
# Three data types:
#
# integers
#
# floating-point numbers
#
# strings

# %% [markdown]
# Question 4
#
# An expression is a combination of values, variables, and operators.
#
# Expressions computes and relates between operands.

# %% [markdown]
# Question 5
#
# Expressions evaluates to a single value but statements does not evaluates to a single value

# %% [markdown]
# Question 6
#
# bacon = 22

# %% [markdown]
# Question 7
#
# spamspamspam
# spamspamspam

# %% [markdown]
# Question 8
#
# eggs is valid variable and 100 is not valid variable because variables can not be starts with number.

# %% [markdown]
# Question 9
#
# integer - int()
# floating-point number - float()
# string - str()

# %% [markdown]
# Question 10
#
# Error in expression is because concatenation is not possiblle for int data type and string data type.

# %%
# Fixing a error
'I have eaten' + ' 99 ' + 'burritos.'
# Out:
# 'I have eaten 99 burritos.'
